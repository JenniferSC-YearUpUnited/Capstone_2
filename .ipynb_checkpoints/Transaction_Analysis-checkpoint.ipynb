# %% [markdown]
# # Transaction Analysis

# %%
# Start by importing numpy, pandas, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Created a variable to work with the file
# Read in the transaction data file and load its contents into the pandas dataframe
df2 = pd.read_csv("transaction_data.csv")
# Called on the variable to view the dataframe
df2
# Out:
#       TransactionID  CustID       Date        Employee  ProductID  \
# 0             10258       1  7/17/2023   Nancy Davolio         32
# 1             10275       2   8/7/2023   Nancy Davolio         24
# 2             10275       2   8/7/2023   Nancy Davolio         59
# 3             10292       3  8/28/2023   Nancy Davolio         20
# 4             10293       4  8/29/2023   Nancy Davolio         18
# ...             ...     ...        ...             ...        ...
# 1348          11016      20  4/10/2025  Anne Dodsworth         31
# 1349          11016      20  4/10/2025  Anne Dodsworth         36
# 1350          11058      82  4/29/2025  Anne Dodsworth         21
# 1351          11058      82  4/29/2025  Anne Dodsworth         60
# 1352          11058      82  4/29/2025  Anne Dodsworth         61
#
#                  ProductName  VendorID              ProductVendor  UnitPrice  \
# 0         Mascarpone Fabioli        14    Formaggi Fortini s.r.l.       25.6
# ...

# %% [markdown]
# *Here, I have my csv file in a dataframe and quickly glancing at the dataframe I can tell I have 1353 rows and 13 columns*

# %%
# To view the first 10 rows of the dataframe I used the .head method
df2.head(10)
# Out:
#    TransactionID  CustID       Date       Employee  ProductID  \
# 0          10258       1  7/17/2023  Nancy Davolio         32
# 1          10275       2   8/7/2023  Nancy Davolio         24
# 2          10275       2   8/7/2023  Nancy Davolio         59
# 3          10292       3  8/28/2023  Nancy Davolio         20
# 4          10293       4  8/29/2023  Nancy Davolio         18
# 5          10293       4  8/29/2023  Nancy Davolio         24
# 6          10293       4  8/29/2023  Nancy Davolio         63
# 7          10293       4  8/29/2023  Nancy Davolio         75
# 8          10304       4  9/12/2023  Nancy Davolio         59
# 9          10304       4  9/12/2023  Nancy Davolio         71
#
#               ProductName  VendorID                    ProductVendor  \
# 0      Mascarpone Fabioli        14          Formaggi Fortini s.r.l.
# 1        Guaran Fantstica        10        Refrescos Americanas LTDA
# 2    Raclette Courdavault        28                      Gai pturage
# ...

# %% [markdown]
# *Upon looking at the data I can see that it has repeating values in some columns but overall the data is unorganized by having multiple IDs to identify a certain thing. It looks like there is data for each transaction that was processed by each employee and which customer made the purchase, product name and product ID to identify each product name, vendor name and vendor ID to identify each vendor, along with unitprice, for each product and the quantity that was purchased, subtotal or revenue before taxes, and transaction total for each transaction after taxes are applied and identified by the transaction ID. I also noticed some of the values are integers or floats. I will inspect the data using some other methods.*

# %%
# To see the summary info inclduing data types by column using the .info() method
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1353 entries, 0 to 1352
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  1353 non-null   int64
#  1   CustID         1353 non-null   int64
#  2   Date           1353 non-null   object
#  3   Employee       1353 non-null   object
#  4   ProductID      1353 non-null   int64
#  5   ProductName    1353 non-null   object
#  6   VendorID       1353 non-null   int64
#  7   ProductVendor  1353 non-null   object
#  8   UnitPrice      1353 non-null   float64
#  9   Quantity       1353 non-null   int64
#  10  Subtotal       1353 non-null   float64
#  11  Tax(8%)        1353 non-null   float64
#  12  OrderTotal     1353 non-null   float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 137.5+ KB

# %% [markdown]
# *Upon looking at the info results I can determine there are 1353 records with 13 total columns. Out of those 13 columns 4 columns contain values that are floats, 5 columns contain values that are integers, and 4 columns contain values that are strings or mixed datatypes. All the columns have the same amount of records so it seems like there are no missing values.*

# %%
# To see statistics on numeric columns I used the .describe attribute.
df2.describe()
# Out:
#        TransactionID       CustID    ProductID     VendorID    UnitPrice  \
# count    1353.000000  1353.000000  1353.000000  1353.000000  1353.000000
# mean    10661.179601    38.942350    40.389505    14.318551    25.908899
# std       243.094311    25.056615    22.277628     8.217175    28.613063
# min     10248.000000     1.000000     1.000000     1.000000     2.000000
# 25%     10454.000000    17.000000    21.000000     7.000000    12.000000
# 50%     10656.000000    35.000000    41.000000    14.000000    18.400000
# 75%     10864.000000    60.000000    60.000000    21.000000    31.230000
# max     11077.000000    89.000000    77.000000    29.000000   263.500000
#
#           Quantity     Subtotal      Tax(8%)   OrderTotal
# count  1353.000000  1353.000000  1353.000000  1353.000000
# mean     12.631929   324.537568    25.962971   350.500540
# std       6.395421   403.982507    32.318600   436.301107
# min       1.000000     4.800000     0.380000     5.180000
# ...

# %% [markdown]
# *Upon looking at the statistical summary on numerical data and I get the count for records across 9 columns and they are all the same which means that we do not have any missing values. Then, We have the mean of the values in each column, ( which shows that the average unit price is closer to 26, the average quantity of each item is closer to 6, average subtotal is about 404, average taxes based on 8 percent on a transaction is about 26, and the average order total of each transaction is about 350), then is the standard deviation or the number that shows how spread out the data values are compared to the average in each column,( which looks like the vendor ID number is closer to the mean and the order total is all over the place) then I get the min value of all the values in each column, I also get the max value of all the values in each column at the bottom. Finally, I get the percentiles where the data values of each column falls under ( which the unit price value of 12 falls under the 25 percentile and unit price value of 18 falls under 50 percentile, then the unitprice value of 31 falls under the 75 percentile). Overall, this helps us understand how the data is shaped.*

# %%
# To identify the nonunuique records I used the duplicated method()
df2.duplicated()
# to view I called on the first 50 
df2.head(50)
# Out:
#     TransactionID  CustID        Date       Employee  ProductID  \
# 0           10258       1   7/17/2023  Nancy Davolio         32
# 1           10275       2    8/7/2023  Nancy Davolio         24
# 2           10275       2    8/7/2023  Nancy Davolio         59
# 3           10292       3   8/28/2023  Nancy Davolio         20
# 4           10293       4   8/29/2023  Nancy Davolio         18
# 5           10293       4   8/29/2023  Nancy Davolio         24
# 6           10293       4   8/29/2023  Nancy Davolio         63
# 7           10293       4   8/29/2023  Nancy Davolio         75
# 8           10304       4   9/12/2023  Nancy Davolio         59
# 9           10304       4   9/12/2023  Nancy Davolio         71
# 10          10306       5   9/16/2023  Nancy Davolio         30
# 11          10306       5   9/16/2023  Nancy Davolio         53
# 12          10306       5   9/16/2023  Nancy Davolio         54
# 13          10311       6   9/20/2023  Nancy Davolio         42
# ...

# %% [markdown]
# *Upon inspection I do not see any values that are duplicated except for the transaction ID which could mean a different products were purchase by the same customer and each unit price, quantity, subtotal,tax, and order total was for that specific product in the same or only transaction*

# %%
# I wanted to see if any of the rows would drop by using the drop_duplicates method to remove duplicate records
df2.drop_duplicates()
# Out:
#       TransactionID  CustID       Date        Employee  ProductID  \
# 0             10258       1  7/17/2023   Nancy Davolio         32
# 1             10275       2   8/7/2023   Nancy Davolio         24
# 2             10275       2   8/7/2023   Nancy Davolio         59
# 3             10292       3  8/28/2023   Nancy Davolio         20
# 4             10293       4  8/29/2023   Nancy Davolio         18
# ...             ...     ...        ...             ...        ...
# 1348          11016      20  4/10/2025  Anne Dodsworth         31
# 1349          11016      20  4/10/2025  Anne Dodsworth         36
# 1350          11058      82  4/29/2025  Anne Dodsworth         21
# 1351          11058      82  4/29/2025  Anne Dodsworth         60
# 1352          11058      82  4/29/2025  Anne Dodsworth         61
#
#                  ProductName  VendorID              ProductVendor  UnitPrice  \
# 0         Mascarpone Fabioli        14    Formaggi Fortini s.r.l.       25.6
# ...

# %% [markdown]
# *However, since no single row shares the same values, the amount of records remain the same.*

# %%
# Here I am grouping the data then apply the mean aggregation to Unitprice and Subtotal to get the average price for and average total sales for each product
df2.groupby("ProductID")[["UnitPrice","Subtotal"]].mean()
# Out:
#            UnitPrice    Subtotal
# ProductID
# 1          16.892308  198.830769
# 2          18.344828  256.041379
# 3           9.666667  133.333333
# 4          20.166667  266.566667
# 5          19.610000  275.330000
# ...              ...         ...
# 73         14.333333  183.333333
# 74          8.888889  143.111111
# 75          7.290741   91.679630
# 76         16.992000  213.840000
# 77         12.064000  140.920000
#
# [77 rows x 2 columns]

# %% [markdown]
# *Looking at the dataframe that was returned when I applied this aggregation I see that out of the first 5 records the average total price before taxes for product 5 is the hightest with an average of about 275 and for the last 5 records I can see that the average total price before taxes for product 75 is the lowest with an average of about 92. Which give us the average revenue per product*

# %%
# Here I am grouping the data by each customer and then calcuating the average tax and average order total for each customer
df2.groupby("CustID")[["Tax(8%)","OrderTotal"]].mean()
# Out:
#           Tax(8%)   OrderTotal
# CustID
# 1       38.837742   524.304839
# 2       16.040833   216.545000
# 3       43.113000   582.025000
# 4       30.231538   408.121923
# 5        8.385000   113.191429
# ...           ...          ...
# 85      28.890000   390.011538
# 86       4.030000    54.430000
# 87      83.940000  1133.206667
# 88      13.965556   188.543333
# 89      32.658750   440.896250
#
# [89 rows x 2 columns]

# %% [markdown]
# *Upon looking at the dataframe that was returned when I applied this aggregation I see that the average tax on the purchase based on 8 percent is the highest when the average totalprice after taxes is higher.*

# %% [markdown]
# # Here I am grouping the data by date and then calculating the total or sum of the subtotal or price before taxes for each date
# df2.groupby("Date")["Subtotal"].sum()

# %% [markdown]
# *For the first 5 records I see the highest total price or revenue before taxes was on January 1st. For the last 5 records I see the highest otal price or revenue before taxes was on September 8th.*

# %%
# For the next aggregataion I created a variable to store a list of two columns to use in my next function
list = ["Quantity","Subtotal"]

# %%
# Here I am adding a new column named sum which is the total of quantity and subtotal columns and I want the sum across each row.
df2["Sum"] = df2[list].sum(axis=1)
# Call on the dataframe to view 
df2
# Out:
#       TransactionID  CustID       Date        Employee  ProductID  \
# 0             10258       1  7/17/2023   Nancy Davolio         32
# 1             10275       2   8/7/2023   Nancy Davolio         24
# 2             10275       2   8/7/2023   Nancy Davolio         59
# 3             10292       3  8/28/2023   Nancy Davolio         20
# 4             10293       4  8/29/2023   Nancy Davolio         18
# ...             ...     ...        ...             ...        ...
# 1348          11016      20  4/10/2025  Anne Dodsworth         31
# 1349          11016      20  4/10/2025  Anne Dodsworth         36
# 1350          11058      82  4/29/2025  Anne Dodsworth         21
# 1351          11058      82  4/29/2025  Anne Dodsworth         60
# 1352          11058      82  4/29/2025  Anne Dodsworth         61
#
#                  ProductName  VendorID              ProductVendor  UnitPrice  \
# 0         Mascarpone Fabioli        14    Formaggi Fortini s.r.l.       25.6
# ...

# %% [markdown]
# *Upon looking at the dataframe I can see the first 5 records and the lowest sum for quanity sold and revenue before tax about 55 and for the last 5 records the lowest sum for quantity sold and revenue before tax is about 33 which means that sales and revenue before tax were behaving differently across different dates.*

# %%
# Here I am creating a figure of size 15in wide, 10 in tall
plt.figure(figsize=(15,10))
# I wanted a line plot to show the index of the dataframe which would represent the time and then sum columns of quantity sold and subtotal or revenue before tax then added the marker to be in a shape of o and linestyle to be a regular dash and set a color for fill of the markers and made the color green
plt.plot(df2.index, df2["Sum"],marker ='o',mfc="y", linestyle='-', color= "green")
# Here I am setting the x label to the index that represents time
plt.xlabel("Index")
# Here I am setting the y labto sum of the values being plotted
plt.ylabel("Sum")
# Then I add my title describing my plot
plt.title("Sum for Quantity Sold and Revenue over Time")
# I wanted to display the grid for better readability 
plt.grid(True)
# Finally, display the plot
plt.show()

# %% [markdown]
# *I am visualizing the sum of sales and revenue before tax over time showing that they were behaving differently across different dates meaning the sales and revenue were high or stronger during some dates or time. I would have had to sort the dates to better understand this behavior over time. However, this would be helpful to see what dates the business needs to work on promotions or sales to achieve better revenue.*
