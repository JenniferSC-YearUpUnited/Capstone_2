# %% [markdown]
# # Data Cleaning

# %%
# Start by importing numpy and pandas
import numpy as np
import pandas as pd

# %%
# Created a variable to work with the file 
# Read in the customer data file and load its contents into the pandas dataframe
# Used the input function to get the user input from the keyboard
df1 = pd.read_csv(input(''))
# Called on the variable to view the dataframe
df1
# customer_list_updated.csv
# Out:
#  customer_list_updated.csv
#        cust_id|date|time|name|email|phone|sms-opt-out
# 0    1|2023-03-15|08:45:12|Rachel|rachel@centralper...
# 1    2|2023-05-22|12:30:45|R&! Geller|rossg@central...
# 2    3|2023-07-09|18:15:27|Monica Geller|chefmonica...
# 3    4|2023-09-01|21:05:33|Chandler Bing|chandlerb@...
# 4    5|2023-11-18|14:22:10|Joey|howyoudoing@central...
# ..                                                 ...
# 516  517|2024-02-15|11:30:30|Perry the Platypus|age...
# 517  518|2024-05-01|15:55:45|Baljeet|baljeet@danvil...
# 518  519|2023-03-05|09:20:00|Buford|buford@danville...
# 519  520|2023-05-18|13:45:15|Vanessa D.^|vanessa@da...
# 520  521|2023-08-01|18:10:30|Linda Flynn-Fletcher|l...
#
# [521 rows x 1 columns]

# %% [markdown]
# *To load the data as a DataFrame will use the above code*
# *Asking the user to input the file name for the file to be processed*
# *Assign to a variable to save it into a dataframe*
# *The data is in an awkward format will need to separate customer records into columns*

# %%
# To separate the data into columns I used the sep parameter which speicifies the delimiter that separates the values in the file by telling pandas that the columns in the file are separated by pipes instead of commas.
df1 = pd.read_csv(input(''), sep = '|')
# Called on the variable to view the dataframe again
df1
#customer_list_updated.csv
# Out:
#  customer_list_updated.csv
#      cust_id        date      time                  name  \
# 0          1  2023-03-15  08:45:12                Rachel
# 1          2  2023-05-22  12:30:45            R&! Geller
# 2          3  2023-07-09  18:15:27         Monica Geller
# 3          4  2023-09-01  21:05:33         Chandler Bing
# 4          5  2023-11-18  14:22:10                  Joey
# ..       ...         ...       ...                   ...
# 516      517  2024-02-15  11:30:30    Perry the Platypus
# 517      518  2024-05-01  15:55:45               Baljeet
# 518      519  2023-03-05  09:20:00                Buford
# 519      520  2023-05-18  13:45:15           Vanessa D.^
# 520      521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# ...

# %% [markdown]
# *In order to separate the customer recordsinto columns I used the separator parameter to display the values without the pipe symbol*
# *Each record is then separated where the pipe symbol is located and separated into their perspective columns*
# *Now, if I do it this way, I can make it easier to preview the data*
# *Finally, call on the variable to display*

# %%
# Using the info method to get a summary of the dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       521 non-null    int64
#  1   date          521 non-null    object
#  2   time          521 non-null    object
#  3   name          521 non-null    object
#  4   email         521 non-null    object
#  5   phone         520 non-null    object
#  6   sms-opt-out   520 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 28.6+ KB

# %% [markdown]
# *Checking the structure after having separated the customer records into columns using the info attribute*
# *This will show the summary infromation about df1 to help me identify any irregularities in the columns*
# *Here I can tell I have 521 records*
# *I can tell have a total of 7 columns*
# *The Dtype for most of this data is string except for the customer id which an integer of 64 bytes*
# *The amount of non-null values or any value that is not none is 521 entries compared to 520 non null values in the message opt out column where there could be a missing value and 520 phone non null values in phone,
# which means there could be a missing phone number in that column*
# *I will then need to check the contents*

# %%
# To view the first 50 rows of the dataframe
df1.head(51)
# Out:
#     cust_id        date      time            name  \
# 0         1  2023-03-15  08:45:12          Rachel
# 1         2  2023-05-22  12:30:45      R&! Geller
# 2         3  2023-07-09  18:15:27   Monica Geller
# 3         4  2023-09-01  21:05:33   Chandler Bing
# 4         5  2023-11-18  14:22:10            Joey
# 5         6  2024-01-05  10:55:49      P&! Buffay
# 6         7  2024-02-14  16:40:05         Gunther
# 7         8  2023-04-20  09:15:30          Janice
# 8         9  2023-06-30  13:50:55        Mike H.^
# 9        10  2023-08-25  17:25:10           Emily
# 10       11  2023-04-12  09:20:30    Walter White
# 11       12  2023-06-25  13:45:50   Jesse Pinkman
# 12       13  2023-08-03  17:30:15      Skyler W.^
# 13       14  2023-10-19  20:05:40    Saul Goodman
# 14       15  2024-02-28  11:15:25    H&! Schrader
# 15       16  2024-03-10  15:50:35       Gus Fring
# 16       17  2024-04-22  19:25:50        Mike E.^
# 17       18  2023-05-14  10:30:45       Marie S.^
# ...

# %% [markdown]
# *looking at the first 50 records with .head() attribute. With this, I'm able to see that the name values have stray characters*
# *Will need to take out the caret symbol(^),([']) also the (&!) symbols*
# *Format the phone numbers correctly*
# *Decide what to do with the missing values in phone column and the message opt out column*

# %%
# Replacing the stray characters in the dataframe
df1["name"] = df1["name"].str.replace("^","")
df1
# Out:
#      cust_id        date      time                  name  \
# 0          1  2023-03-15  08:45:12                Rachel
# 1          2  2023-05-22  12:30:45            R&! Geller
# 2          3  2023-07-09  18:15:27         Monica Geller
# 3          4  2023-09-01  21:05:33         Chandler Bing
# 4          5  2023-11-18  14:22:10                  Joey
# ..       ...         ...       ...                   ...
# 516      517  2024-02-15  11:30:30    Perry the Platypus
# 517      518  2024-05-01  15:55:45               Baljeet
# 518      519  2023-03-05  09:20:00                Buford
# 519      520  2023-05-18  13:45:15            Vanessa D.
# 520      521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# ...

# %% [markdown]
# *I replaced the caret symbol (^) first by pulling the name column in brackets, this will specify the column I want to make changes to*
# *I then applied the .str method to allow me to apply string functions to the entire column which contains strings along with the. replace method to replace the caret symbol with nothing since its at the very end of the name string.*
# *I then went ahead and assigned it back to the same datafram and same column to save the changes*
# *Finally I called on it to view the output*

# %%
# Replacing more stray character in the dataframe
df1["name"] = df1["name"].str.replace("&!",".")
df1
# Out:
#      cust_id        date      time                  name  \
# 0          1  2023-03-15  08:45:12                Rachel
# 1          2  2023-05-22  12:30:45             R. Geller
# 2          3  2023-07-09  18:15:27         Monica Geller
# 3          4  2023-09-01  21:05:33         Chandler Bing
# 4          5  2023-11-18  14:22:10                  Joey
# ..       ...         ...       ...                   ...
# 516      517  2024-02-15  11:30:30    Perry the Platypus
# 517      518  2024-05-01  15:55:45               Baljeet
# 518      519  2023-03-05  09:20:00                Buford
# 519      520  2023-05-18  13:45:15            Vanessa D.
# 520      521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# ...

# %% [markdown]
# *I then replaced the (&) and (!) symbol together since I seen that both of them are together for the first 50 records.*
# *This time I replaced it with a period since I noticed they were in between a first intial followed by a last name*
# *I again pulled up the name column in brackets, this will specify the column I want to make changes to*
# *I then applied the .str method to allow me to apply string functions to the entire column which contains strings along with the. replace method*
# *I then went ahead and assigned it to the same dataframe and same column to save the changes*
# *Finally, I called on it to view the output*

# %%
# Noticed another stray character
df1.head(301)
# Out:
#      cust_id        date      time             name  \
# 0          1  2023-03-15  08:45:12           Rachel
# 1          2  2023-05-22  12:30:45        R. Geller
# 2          3  2023-07-09  18:15:27    Monica Geller
# 3          4  2023-09-01  21:05:33    Chandler Bing
# 4          5  2023-11-18  14:22:10             Joey
# ..       ...         ...       ...              ...
# 296      297  2023-03-21  13:35:40       Kira Nerys
# 297      298  2023-05-04  17:00:55              Odo
# 298      299  2023-06-17  20:25:10       Jadzia Dax
# 299      300  2023-07-30  08:50:25    Julian Bashir
# 300      301  2023-09-12  12:15:40  Miles O[']Brien
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# 3      chandlerb@centralperk.coffee  212-555-1004            Y
# ...

# %%
# Replacing the stray character I found
df1["name"] = df1["name"].str.replace("[']","'")
df1
# Out:
#      cust_id        date      time                  name  \
# 0          1  2023-03-15  08:45:12                Rachel
# 1          2  2023-05-22  12:30:45             R. Geller
# 2          3  2023-07-09  18:15:27         Monica Geller
# 3          4  2023-09-01  21:05:33         Chandler Bing
# 4          5  2023-11-18  14:22:10                  Joey
# ..       ...         ...       ...                   ...
# 516      517  2024-02-15  11:30:30    Perry the Platypus
# 517      518  2024-05-01  15:55:45               Baljeet
# 518      519  2023-03-05  09:20:00                Buford
# 519      520  2023-05-18  13:45:15            Vanessa D.
# 520      521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# ...

# %%
# Checking to see that its corrected
df1.head(301)
# Out:
#      cust_id        date      time           name  \
# 0          1  2023-03-15  08:45:12         Rachel
# 1          2  2023-05-22  12:30:45      R. Geller
# 2          3  2023-07-09  18:15:27  Monica Geller
# 3          4  2023-09-01  21:05:33  Chandler Bing
# 4          5  2023-11-18  14:22:10           Joey
# ..       ...         ...       ...            ...
# 296      297  2023-03-21  13:35:40     Kira Nerys
# 297      298  2023-05-04  17:00:55            Odo
# 298      299  2023-06-17  20:25:10     Jadzia Dax
# 299      300  2023-07-30  08:50:25  Julian Bashir
# 300      301  2023-09-12  12:15:40  Miles O'Brien
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# 3      chandlerb@centralperk.coffee  212-555-1004            Y
# ...

# %% [markdown]
# *I then replaced the bracket with the apstrophe symbol with just the 'or apostrophe in between O and Brien.*
# *I again pulled up the name column in brackets, this will specify the column I want to make changes to*
# *I then applied the .str method to allow me to apply string functions to the entire column which contains strings along with the. replace method*
# *I then went ahead and assigned it to the same dataframe and same column to save the changes*
# *Finally, I called on it to view the output

# %%
# Using the .astype method to convert the dta type of phone to convert the values into strings because the phone numbers contain special characters and treated them as text
# I also got an error if I did not convert them as maybe they were stored as numerical values
df1["phone"] = df1["phone"].astype(str)
df1
# Out:
#      cust_id        date      time                  name  \
# 0          1  2023-03-15  08:45:12                Rachel
# 1          2  2023-05-22  12:30:45             R. Geller
# 2          3  2023-07-09  18:15:27         Monica Geller
# 3          4  2023-09-01  21:05:33         Chandler Bing
# 4          5  2023-11-18  14:22:10                  Joey
# ..       ...         ...       ...                   ...
# 516      517  2024-02-15  11:30:30    Perry the Platypus
# 517      518  2024-05-01  15:55:45               Baljeet
# 518      519  2023-03-05  09:20:00                Buford
# 519      520  2023-05-18  13:45:15            Vanessa D.
# 520      521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# ...

# %% [markdown]
# *I converted the column to a specific data type in this case to a string to make sure it's treated as a string to handle formatting.*
# *Then assigned it back to the phone column in the dataframe*

# %%
# I use a loop to iterate over the phone column and used i for each phone number. 
for i in df1["phone"]:
    # print each individual phone number
    print(i)
    # for each phone number print the length of characters
    print(len(i))
# Out:
# 212-555-1001
# 12
# 212-555-1002
# 12
# 212-555-1003
# 12
# 212-555-1004
# 12
# 212-555-1005
# 12
# 212-555-1006
# 12
# 212-555-1007
# 12
# 212-555-1008
# 12
# 212-555-1009
# 12
# 212-555-1010
# 12
# 505-555-2001
# 12
# 505-555-2002
# 12
# 505-555-2003
# 12
# 505-555-2004
# 12
# 505-555-2005
# 12
# 505-555-2006
# 12
# 505-555-2007
# 12
# 505-555-2008
# 12
# 505-555-2009
# 12
# 505-555-2010
# 12
# 123-555-3001
# 12
# 123-555-3002
# 12
# 123-555-3003
# 12
# 123-555-3004
# 12
# 123-555-3005
# 12
# 123-555-3006
# 12
# 123-555-3007
# 12
# 123-555-3008
# 12
# 123-555-3009
# 12
# 123-555-3010
# 12
# 636-555-4001
# 12
# 636-555-4002
# 12
# 636-555-4003
# 12
# 636-555-4004
# 12
# 636-555-4005
# 12
# 636-555-4006
# 12
# 636-555-4007
# 12
# 636-555-4008
# 12
# 636-555-4009
# 12
# 636-555-4010
# 12
# 570-555-5001
# 12
# 570-555-5002
# 12
# 570-555-5003
# 12
# 570-555-5004
# 12
# 570-555-5005
# 12
# 570-555-5006
# 12
# 570-555-5007
# 12
# 570-555-5008
# 12
# 570-555-5009
# 12
# 570-555-5010
# 12
# ...

# %% [markdown]
# *In order to iterate over the phone column, I  need to use a loop so for each phone number I used i.  I then want to print the phone numbers and the length of the individual phone number.*
# *Looking over the phone numbers I noticed the standard length of them are 12 characters*

# %%
# Again iterate over the phone column I used the same loop, for each phone number I used i.
for i in df1["phone"]:
    # checking to see if the length of each phone number is greater than 12
    if len(i) > 12:
        # print phone numbers if the above conidito is true
        print(i)
# Out:
# 1701-555-2201
# 1701-555-2202
# 1701-555-2203
# 1701-555-2204
# 1701-555-2205
# 1701-555-2206
# 1701-555-2207
# 1701-555-2208
# 1701-555-2209
# 1701-555-2210

# %% [markdown]
# *Then, I then wanted to see which phone numbers are greater than 12 characters long so I did another loop and to filter or check each phone number I again used i and if this condition is true then the phone numbers that are greater than 12 characters long will print*

# %%
# Here I used loc method to find rows where the phone column has more than 12 characters and at the same time modify my original dataframe
# Then applied the lstrip(1) to remove the left character
df1.loc[df1["phone"].str.len() > 12, "phone"] = df1["phone"].str.lstrip("1")
df1
# Out:
#      cust_id        date      time                  name  \
# 0          1  2023-03-15  08:45:12                Rachel
# 1          2  2023-05-22  12:30:45             R. Geller
# 2          3  2023-07-09  18:15:27         Monica Geller
# 3          4  2023-09-01  21:05:33         Chandler Bing
# 4          5  2023-11-18  14:22:10                  Joey
# ..       ...         ...       ...                   ...
# 516      517  2024-02-15  11:30:30    Perry the Platypus
# 517      518  2024-05-01  15:55:45               Baljeet
# 518      519  2023-03-05  09:20:00                Buford
# 519      520  2023-05-18  13:45:15            Vanessa D.
# 520      521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# ...

# %% [markdown]
# *I used the .loc[] to change the values directly in the dataframe without looping through them again and find specific rows where the condition is true and the phone column where I want to change the values, then checking for phone numbers longer than 12 characters and then those phone numbers that are in fact more than 12 characters, the (1) gets strip away.*

# %%
# checking to see the output
df1_cleaned.head(289)
# Out:
#      cust_id        date      time             name  \
# 0          1  2023-03-15  08:45:12           Rachel
# 1          2  2023-05-22  12:30:45        R. Geller
# 2          3  2023-07-09  18:15:27    Monica Geller
# 3          4  2023-09-01  21:05:33    Chandler Bing
# 4          5  2023-11-18  14:22:10             Joey
# ..       ...         ...       ...              ...
# 284      285  2024-03-15  12:10:30     Pirate Jenny
# 285      286  2023-01-01  08:00:00  Jean-Luc Picard
# 286      287  2023-02-14  12:25:15    William Riker
# 287      288  2023-03-27  15:50:30             Data
# 288      289  2023-05-10  19:15:45  Geordi La Forge
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001           N
# 1          rossg@centralperk.coffee  212-555-1002           N
# 2     chefmonica@centralperk.coffee  212-555-1003           N
# 3      chandlerb@centralperk.coffee  212-555-1004           Y
# ...

# %% [markdown]
# *I want to make sure it did save the changes to the dataframe where it's suppose to.*

# %%
# checking to see the output
df1.head(237)
# Out:
#      cust_id        date      time           name  \
# 0          1  2023-03-15  08:45:12         Rachel
# 1          2  2023-05-22  12:30:45      R. Geller
# 2          3  2023-07-09  18:15:27  Monica Geller
# 3          4  2023-09-01  21:05:33  Chandler Bing
# 4          5  2023-11-18  14:22:10           Joey
# ..       ...         ...       ...            ...
# 232      233  2023-12-14  19:25:10   Hannah McKay
# 233      234  2024-01-27  07:50:25   Harry Morgan
# 234      235  2024-03-11  11:15:40   Lumen Pierce
# 235      236  2023-03-03  08:45:15  Piper Chapman
# 236      237  2023-04-16  13:10:30     Alex Vause
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# 3      chandlerb@centralperk.coffee  212-555-1004            Y
# ...

# %% [markdown]
# *I want to make sure other numbers containing 1701 did not change*

# %%
# checking to see the output
df1.head(363)
# Out:
#      cust_id        date      time              name  \
# 0          1  2023-03-15  08:45:12            Rachel
# 1          2  2023-05-22  12:30:45         R. Geller
# 2          3  2023-07-09  18:15:27     Monica Geller
# 3          4  2023-09-01  21:05:33     Chandler Bing
# 4          5  2023-11-18  14:22:10              Joey
# ..       ...         ...       ...               ...
# 358      359  2024-06-11  19:35:25          Log Lady
# 359      360  2023-02-17  08:00:50     Leland Palmer
# 360      361  2023-05-02  13:25:15        Lucy Moran
# 361      362  2023-02-10  08:15:25  Wednesday Addams
# 362      363  2023-04-23  12:40:50   Morticia Addams
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# 3      chandlerb@centralperk.coffee  212-555-1004            Y
# ...

# %% [markdown]
# *Again, I want to make sure other numbers containing 1701 did nto change*

# %%
# Dealing with the nan values
df1.head(302)
# Out:
#      cust_id        date      time           name  \
# 0          1  2023-03-15  08:45:12         Rachel
# 1          2  2023-05-22  12:30:45      R. Geller
# 2          3  2023-07-09  18:15:27  Monica Geller
# 3          4  2023-09-01  21:05:33  Chandler Bing
# 4          5  2023-11-18  14:22:10           Joey
# ..       ...         ...       ...            ...
# 297      298  2023-05-04  17:00:55            Odo
# 298      299  2023-06-17  20:25:10     Jadzia Dax
# 299      300  2023-07-30  08:50:25  Julian Bashir
# 300      301  2023-09-12  12:15:40  Miles O'Brien
# 301      302  2023-02-14  08:15:25  Buffy Summers
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001            N
# 1          rossg@centralperk.coffee  212-555-1002            N
# 2     chefmonica@centralperk.coffee  212-555-1003            N
# 3      chandlerb@centralperk.coffee  212-555-1004            Y
# ...

# %% [markdown]
# *Based on my info summary I know there is one missing value in the phone column and sms opt out column which from looking at previous output of the dataframe it's the columns for Miles O'Brien.*

# %%
# Here I am looking for any string value in the dataframe column for phone that has the word nan and replacing it with unknown
# Then I am saving the changes back to the dataframe under column phone
df1["phone"] = df1["phone"].str.replace("nan", "unknown
# Checking the output of the saved changes
df1.head(302)
# Out:
#      cust_id        date      time           name  \
# 0          1  2023-03-15  08:45:12         Rachel
# 1          2  2023-05-22  12:30:45      R. Geller
# 2          3  2023-07-09  18:15:27  Monica Geller
# 3          4  2023-09-01  21:05:33  Chandler Bing
# 4          5  2023-11-18  14:22:10           Joey
# ..       ...         ...       ...            ...
# 297      298  2023-05-04  17:00:55            Odo
# 298      299  2023-06-17  20:25:10     Jadzia Dax
# 299      300  2023-07-30  08:50:25  Julian Bashir
# 300      301  2023-09-12  12:15:40  Miles O'Brien
# 301      302  2023-02-14  08:15:25  Buffy Summers
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001           N
# 1          rossg@centralperk.coffee  212-555-1002           N
# 2     chefmonica@centralperk.coffee  212-555-1003           N
# 3      chandlerb@centralperk.coffee  212-555-1004           Y
# ...

# %% [markdown]
# *I believe when I converted the phone column into a string, it also turned the missing value to a string,
# because I kept getting an error when I tried using the fillna attribute. It was not reconizing the nan as a missing value
# which is why I used replaced instead*

# %%
# printing out the list of columns to see if there are any extra white spaces I need to remove
# Which the out shows that there is whitespace in the column for message opt out 
print(df1.columns)
# Out:
# Index(['cust_id', 'date', 'time', 'name', 'email', 'phone', 'sms-opt-out'], dtype='object')

# %% [markdown]
# *When I was using the fillna method to change the missing value in the column I kept getting an error message that the column did not exist, so I had to check if in fact it did exit with printing out the column list*

# %%
# Here I am pulling up the list of columns again and using the string strip methods to remove white spaces in the column names
# Then to save the changes to the original dataframe I reassigned the columns back to df1
df1.columns = df1.columns.str.strip()
# Checking on the output to make sure it was updated
print(df1.columns)
# Out:
# Index(['cust_id', 'date', 'time', 'name', 'email', 'phone', 'sms-opt-out'], dtype='object')

# %% [markdown]
# *Double checking to make sure the white space was removed which is why I decided to print the output*

# %%
# Here I used the fillna method to fill in the missing alue in the message opt out colum and used a diction key value set to specify the column name and the value I wanted instead 
# Since I did not create a new table and I needed to save the changes in the original dataframe I used inplace attribute and made that equal to true to change the dataframe directly.
df1.fillna({"sms-opt-out": "unknown"},inplace=True)
# Checking to see the output was indeed saved to the dataframe
df1.head(302)
# Out:
#      cust_id        date      time           name  \
# 0          1  2023-03-15  08:45:12         Rachel
# 1          2  2023-05-22  12:30:45      R. Geller
# 2          3  2023-07-09  18:15:27  Monica Geller
# 3          4  2023-09-01  21:05:33  Chandler Bing
# 4          5  2023-11-18  14:22:10           Joey
# ..       ...         ...       ...            ...
# 297      298  2023-05-04  17:00:55            Odo
# 298      299  2023-06-17  20:25:10     Jadzia Dax
# 299      300  2023-07-30  08:50:25  Julian Bashir
# 300      301  2023-09-12  12:15:40  Miles O'Brien
# 301      302  2023-02-14  08:15:25  Buffy Summers
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001           N
# 1          rossg@centralperk.coffee  212-555-1002           N
# 2     chefmonica@centralperk.coffee  212-555-1003           N
# 3      chandlerb@centralperk.coffee  212-555-1004           Y
# ...

# %% [markdown]
# *Based on internet research related to SMS marketing is that you must obtain express written consent from people before sending them promotional text messages or it may lead to lawsuits. Therefore, I reflected these missing values as unknown as we do not have a phone number for Miles O'Brien and without that we do not have a way to obtain consent from him to opt out or in*

# %%
# Here I created a variable to specify the path of where the file is I had to open up my file explorer and find the path and pasted it here.
# I had to use the raw string to make sure that the backslahes are not treated as escape characters in the file path
file_path= r"C:\Users\Student\YUU-LearnToCode\DataAnalytics\week_8\Capstone_2\customer_list_export.csv"
# Then I created another variable to hold my file name and to not get confused with the origina file name I renamed it customer list export to easier see that that was the exported file
# customer_list_export.csv
file_name = "customer_list_export.csv"


#I then saved the data from df1 into the csv file at the folder location I specified in the file path using the .to_csv function.
# I also specified to not save the index or row numbers in the saved file
df1.to_csv(file_path, index=False)

# I then created a print statement using the f string format to include the variable I created for the file name and file path in the final status message
print(f" Your file {file_name} is saved in {file_path}")
# Out:
#  Your file customer_list_export.csv is saved in C:\Users\Student\YUU-LearnToCode\DataAnalytics\week_8\Capstone_2\customer_list_export.csv

# %% [markdown]
# *Checked to see file path in file explorer and opened up the exported file to confirm*
